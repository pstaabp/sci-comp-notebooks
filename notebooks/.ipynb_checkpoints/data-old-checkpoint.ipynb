# %% [raw]
# using RDatasets,StatsPlots

# %%
RDatasets.packages()
# Out:
# 33×2 DataFrame. Omitted printing of 1 columns
# │ Row │ Package      │
# │     │ String       │
# ├─────┼──────────────┤
# │ 1   │ COUNT        │
# │ 2   │ Ecdat        │
# │ 3   │ HSAUR        │
# │ 4   │ HistData     │
# │ 5   │ ISLR         │
# │ 6   │ KMsurv       │
# │ 7   │ MASS         │
# │ 8   │ SASmixed     │
# │ 9   │ Zelig        │
# │ 10  │ adehabitatLT │
# ⋮
# │ 23  │ plyr         │
# │ 24  │ pscl         │
# │ 25  │ psych        │
# │ 26  │ quantreg     │
# │ 27  │ reshape2     │
# │ 28  │ robustbase   │
# │ 29  │ rpart        │
# │ 30  │ sandwich     │
# │ 31  │ sem          │
# │ 32  │ survival     │
# │ 33  │ vcd          │

# %%
RDatasets.datasets("datasets")
# Out:
# 50×5 DataFrame. Omitted printing of 3 columns
# │ Row │ Package  │ Dataset          │
# │     │ String   │ String           │
# ├─────┼──────────┼──────────────────┤
# │ 1   │ datasets │ BOD              │
# │ 2   │ datasets │ CO2              │
# │ 3   │ datasets │ Formaldehyde     │
# │ 4   │ datasets │ HairEyeColor     │
# │ 5   │ datasets │ InsectSprays     │
# │ 6   │ datasets │ LifeCycleSavings │
# │ 7   │ datasets │ Loblolly         │
# │ 8   │ datasets │ OrchardSprays    │
# │ 9   │ datasets │ PlantGrowth      │
# │ 10  │ datasets │ Puromycin        │
# ⋮
# │ 40  │ datasets │ quakes           │
# │ 41  │ datasets │ randu            │
# │ 42  │ datasets │ rivers           │
# │ 43  │ datasets │ rock             │
# │ 44  │ datasets │ sleep            │
# │ 45  │ datasets │ stackloss        │
# │ 46  │ datasets │ swiss            │
# │ 47  │ datasets │ trees            │
# │ 48  │ datasets │ volcano          │
# │ 49  │ datasets │ warpbreaks       │
# ...

# %%
iris = RDatasets.dataset("datasets","iris")
# Out:
# 150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa       │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa       │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa       │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa       │
# ...

# %%
iris[:PetalLength]
# Out:
# 150-element Array{Float64,1}:
#  1.4
#  1.4
#  1.3
#  1.5
#  1.4
#  1.7
#  1.4
#  1.5
#  1.4
#  1.5
#  1.5
#  1.6
#  1.4
#  ⋮
#  4.8
#  5.4
#  5.6
#  5.1
#  5.1
#  5.9
#  5.7
#  5.2
#  5.0
#  5.2
#  5.4
#  5.1

# %%
iris[:SepalWidth][11:20]
# Out:
# 10-element Array{Float64,1}:
#  3.7
#  3.4
#  3.0
#  3.0
#  4.0
#  4.4
#  3.9
#  3.5
#  3.8
#  3.8

# %%
plot(iris[:SepalLength],iris[:SepalWidth],seriestype=:scatter)

# %%
savefig("../images/ch14/plot01.png")

# %%
@df iris scatter(:SepalLength,:SepalWidth)

# %%
df = DataFrame(A = 1:4, B = ["M", "F", "F", "M"], C=[3.0,2.5,pi,-2.3])
# Out:
# 4×3 DataFrame
# │ Row │ A     │ B      │ C       │
# │     │ Int64 │ String │ Float64 │
# ├─────┼───────┼────────┼─────────┤
# │ 1   │ 1     │ M      │ 3.0     │
# │ 2   │ 2     │ F      │ 2.5     │
# │ 3   │ 3     │ F      │ 3.14159 │
# │ 4   │ 4     │ M      │ -2.3    │

# %%
size(df)
# Out:
# (4, 3)

# %%
eltypes(df)
# Out:
# 3-element Array{DataType,1}:
#  Int64
#  String
#  Float64

# %%
first(df,2)
# Out:
# 2×3 DataFrame
# │ Row │ A     │ B      │ C       │
# │     │ Int64 │ String │ Float64 │
# ├─────┼───────┼────────┼─────────┤
# │ 1   │ 1     │ M      │ 3.0     │
# │ 2   │ 2     │ F      │ 2.5     │

# %%
@df iris scatter(:SepalLength,:SepalWidth,group=:Species)

# %%
savefig("../images/ch14/plot02.png")

# %%
?mean
# Out:
# search: weighted_color_mean SegmentationFault macroexpand @macroexpand
#
# Couldn't find mean
# Perhaps you meant melt, map, max, min, head, atan, read, real, tan, Real or Meta
#   No documentation found.
#
#   Binding mean does not exist.

# %%
using StatsBase

# %%
mean(iris[:SepalLength])
# Out:
# 5.843333333333334

# %%
mean_and_std(iris[:SepalLength])
# Out:
# (5.843333333333334, 0.828066127977863)

# %%
using Query
# Out:
# ┌ Info: Recompiling stale cache file /Users/peter/.julia/compiled/v1.1/Query/wGX7b.ji for Query [1a8c2f83-1ff3-5112-b086-8aa67b057ba1]
# └ @ Base loading.jl:1184

# %%
collect(1:10) |> @map(_^2) |> @filter( _ % 2 == 0) |> mean
# Out:
# 44.0
